# %% [markdown]
# # Lesson 36 - ANOVA
#
# * To demonstrate what we are doing, show the variance of and between variables by showing boxplots of 1 variable by 4 categories
#     * Show all with low variance and nearly the same mean
#         * Null Hypothesis
#     * Show again with low variance but very different means
#         * High variance __between__ categories indicates categories are different - leans toward rejecting H0
#         * Low variance between categories indicates categories are not different - leans toward failing to reject H0
#     * Show again with high variance and very different means
#         * High variance __within__ catgories indicates categories are not different - leans toward failing to reject H0
#         * Low variance within categories indicates categories are more different - leans toward rejecting H0
#     * Conclusion depends on both
#         * To reject H0, we want both __high variance between categories__ and __low variance within categories__
#         * $f_{score} = \frac{variance~between~categories}{variance~within~categories}$

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

samples = pd.DataFrame(columns=['Sample A','Sample B','Sample C','Sample D'])
samples['Sample A'] = pd.Series(np.random.randint(5,15,100))
samples['Sample B'] = pd.Series(np.random.randint(5,13,100))
samples['Sample C'] = pd.Series(np.random.randint(6,17,100))
samples['Sample D'] = pd.Series(np.random.randint(4,15,100))

sns.boxplot(data=samples)
plt.title('Low variance between and within groups')
plt.savefig('../images/23_ANOVA1.png')
plt.show()

# %%
samples = pd.DataFrame(columns=['Sample A','Sample B','Sample C','Sample D'])
samples['Sample A'] = pd.Series(np.random.randint(5,15,100))
samples['Sample B'] = pd.Series(np.random.randint(15,23,100))
samples['Sample C'] = pd.Series(np.random.randint(11,22,100))
samples['Sample D'] = pd.Series(np.random.randint(24,35,100))

sns.boxplot(data=samples)
plt.title('High variance between groups and low variance within groups')
plt.savefig('../images/23_ANOVA2.png')
plt.show()

# %%
samples = pd.DataFrame(columns=['Sample A','Sample B','Sample C','Sample D'])
samples['Sample A'] = pd.Series(np.random.randint(-30,35,100))
samples['Sample B'] = pd.Series(np.random.randint(-5,55,100))
samples['Sample C'] = pd.Series(np.random.randint(-20,40,100))
samples['Sample D'] = pd.Series(np.random.randint(10,80,100))

sns.boxplot(data=samples)
plt.title('High variance between and within groups')
plt.savefig('../images/23_ANOVA3.png')
plt.show()
